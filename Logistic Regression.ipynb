# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
df01 = pd.read_csv (r'C:\Users\PROXY INFO\Downloads\titanic-passengers (1).csv', sep = ';')
df01
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df02=df01.drop('Cabin', axis=1)
df02
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
ne=len(df02['Embarked'])
print(ne)
print(df02['Embarked'].value_counts())
# Out:
# 891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df02['Embarked'].fillna('S', inplace=True)
df02
print(df02['Embarked'].value_counts())
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
import seaborn as sns
sns.distplot(df02['Age'], bins=20, hist=True, kde=True, color="Red")

# %%
encaa=LabelEncoder()
df02['Embarked']=encaa.fit_transform(df02['Embarked'])
df02
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
encaa=LabelEncoder()
df02['Survived']=encaa.fit_transform(df02['Survived'])
df02
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df03=df02.drop([ "Ticket","PassengerId","Name"],axis =1)
df03
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       2    male  28.0      0      0  13.0000         2
# 1           0       3    male  25.0      0      0   7.6500         2
# 2           0       3    male  20.0      0      0   7.8542         2
# 3           0       3  female  29.0      0      4  21.0750         2
# 4           0       1    male  31.0      1      0  52.0000         2
# ..        ...     ...     ...   ...    ...    ...      ...       ...
# 886         1       2  female  14.0      1      0  30.0708         0
# 887         0       3    male  22.0      0      0   7.2292         0
# 888         0       3  female  30.0      0      0   8.6625         2
# 889         0       3    male   NaN      0      0   7.8958         2
# 890         1       2  female  19.0      0      0  26.0000         2
#
# [891 rows x 8 columns]

# %%
df03['Sex']=encaa.fit_transform(df02['Sex'])
df03
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0           0       2    1  28.0      0      0  13.0000         2
# 1           0       3    1  25.0      0      0   7.6500         2
# 2           0       3    1  20.0      0      0   7.8542         2
# 3           0       3    0  29.0      0      4  21.0750         2
# 4           0       1    1  31.0      1      0  52.0000         2
# ..        ...     ...  ...   ...    ...    ...      ...       ...
# 886         1       2    0  14.0      1      0  30.0708         0
# 887         0       3    1  22.0      0      0   7.2292         0
# 888         0       3    0  30.0      0      0   8.6625         2
# 889         0       3    1   NaN      0      0   7.8958         2
# 890         1       2    0  19.0      0      0  26.0000         2
#
# [891 rows x 8 columns]

# %%
df03['Age'].fillna(df03['Age'].mean(), inplace=True)
df03.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int32
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int32
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int32
# dtypes: float64(2), int32(3), int64(3)
# memory usage: 45.4 KB

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
x=df03[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
y=df03['Survived']
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.15, random_state=28)
x_test
# Out:
#      Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 287       3    1  55.500000      0      0    8.0500         2
# 621       3    0  25.000000      1      0    7.9250         2
# 395       1    0  36.000000      1      2  120.0000         2
# 273       3    1  31.000000      0      0    7.7750         2
# 155       1    1  48.000000      0      0   26.5500         2
# ..      ...  ...        ...    ...    ...       ...       ...
# 256       3    1  26.000000      2      0    8.6625         2
# 573       3    1  28.000000      0      0    7.8958         2
# 145       2    1  18.000000      0      0   11.5000         2
# 317       3    1  29.699118      0      0    7.7750         2
# 650       3    1  21.000000      0      0    7.7958         2
#
# [134 rows x 7 columns]

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
y_pred=logreg.predict(x_test)
print('Accuracy={:.2f}'.format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.76

# %% [markdown]
# With logistic regression, we have 76% of accuracy. It's a good ratio.

# %%
confusion_matrix=pd.crosstab(y_test,y_pred, rownames=['Actual'],colnames=['Predicted'])
print(confusion_matrix)
# Out:
# Predicted   0   1
# Actual
# 0          70  18
# 1          14  32

# %% [markdown]
# As we can see, the probability of getting a true negatif is higher than true positive.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.81        88
#            1       0.64      0.70      0.67        46
#
#     accuracy                           0.76       134
#    macro avg       0.74      0.75      0.74       134
# weighted avg       0.77      0.76      0.76       134

# %% [markdown]
# # ROC/AUC

# %% [markdown]
# AUC - ROC curve is a performance measurement for classification problem at various thresholds settings. ROC is a probability curve and AUC represents degree or measure of separability. It tells how much model is capable of distinguishing between classes.

# %%
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
def plot_roc_curve(fpr, tpr):
    plt.plot(fpr, tpr, color='red', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
model = RandomForestClassifier()
model.fit(x_train,y_train)
probs = model.predict_proba(x_test)
probs = probs[:, 1]

# %%
auc = roc_auc_score(y_test, probs)
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.83

# %%
fpr, tpr, thresholds = roc_curve(y_test, probs)

# %%
plot_roc_curve(fpr, tpr)
